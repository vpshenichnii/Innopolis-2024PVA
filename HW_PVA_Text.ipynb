# %%
import pandas as pd

# %%
import dask.bag as db

# %%
import bs4
import requests
import string

# %% [markdown]
# ### Взял Мцыри Лермонтова

# %%
url = "https://lib.ru/LITRA/LERMONTOW/mcyri.txt_with-big-pictures.html"
response = requests.get(url)
soup = bs4.BeautifulSoup(response.text, 'html')
text = soup.body.get_text(' ', strip=True)

# %%
text
# Out:
# 'Fb2.zip Epub Содержание Fine HTML Printed version txt(Word,КПК) Lib.ru html М.Ю.Лермонтов. Мцыри Вкушая, вкусих мало меда, и се аз умираю. 1-я Книга Царств 1 Немного лет тому назад, Там, где, сливаяся, шумят, Обнявшись, будто две сестры, Струи Арагвы и Куры, Был монастырь. Из-за горы И нынче видит пешеход Столбы обрушенных ворот, И башни, и церковный свод; Но не курится уж под ним Кадильниц благовонный дым, Не слышно пенье в поздний час Молящих иноков за нас. Теперь один старик седой, Развалин страж полуживой, Людьми и смертию забыт, Сметает пыль с могильных плит, Которых надпись говорит О славе прошлой - и о том, Как, удручен своим венцом, Такой-то царь, в такой-то год, Вручал России свой народ. И божья благодать сошла На Грузию! Она цвела С тех пор в тени своих садов, Не опасаяся врагов, 3а гранью дружеских штыков. 2 Однажды русский генерал Из гор к Тифлису проезжал; Ребенка пленного он вез. Тот занемог, не перенес Трудов далекого пути; Он был, казалось, лет шести, Как серна гор, 
# ...

# %%
type(text)
# Out:
# str

# %%
cl_text = text.lower().translate(str.maketrans('', '', string.punctuation)).translate(str.maketrans('', '', string.digits))

# %%
cl_text
# Out:
# 'fbzip epub содержание fine html printed version txtwordкпк libru html мюлермонтов мцыри вкушая вкусих мало меда и се аз умираю я книга царств  немного лет тому назад там где сливаяся шумят обнявшись будто две сестры струи арагвы и куры был монастырь изза горы и нынче видит пешеход столбы обрушенных ворот и башни и церковный свод но не курится уж под ним кадильниц благовонный дым не слышно пенье в поздний час молящих иноков за нас теперь один старик седой развалин страж полуживой людьми и смертию забыт сметает пыль с могильных плит которых надпись говорит о славе прошлой  и о том как удручен своим венцом такойто царь в такойто год вручал россии свой народ и божья благодать сошла на грузию она цвела с тех пор в тени своих садов не опасаяся врагов а гранью дружеских штыков  однажды русский генерал из гор к тифлису проезжал ребенка пленного он вез тот занемог не перенес трудов далекого пути он был казалось лет шести как серна гор пуглив и дик и слаб и гибок как тростник но в нем мучител
# ...

# %%
with open("input.txt", "w", encoding = 'utf-8') as file:
    file.write(cl_text)

# %%
data = db.read_text('input.txt', encoding = 'utf-8')

# %%
data.compute()
# Out:
# ['fbzip epub содержание fine html printed version txtwordкпк libru html мюлермонтов мцыри вкушая вкусих мало меда и се аз умираю я книга царств  немного лет тому назад там где сливаяся шумят обнявшись будто две сестры струи арагвы и куры был монастырь изза горы и нынче видит пешеход столбы обрушенных ворот и башни и церковный свод но не курится уж под ним кадильниц благовонный дым не слышно пенье в поздний час молящих иноков за нас теперь один старик седой развалин страж полуживой людьми и смертию забыт сметает пыль с могильных плит которых надпись говорит о славе прошлой  и о том как удручен своим венцом такойто царь в такойто год вручал россии свой народ и божья благодать сошла на грузию она цвела с тех пор в тени своих садов не опасаяся врагов а гранью дружеских штыков  однажды русский генерал из гор к тифлису проезжал ребенка пленного он вез тот занемог не перенес трудов далекого пути он был казалось лет шести как серна гор пуглив и дик и слаб и гибок как тростник но в нем мучите
# ...

# %%
data.str.split().compute()
# Out:
# [['fbzip',
#   'epub',
#   'содержание',
#   'fine',
#   'html',
#   'printed',
#   'version',
#   'txtwordкпк',
#   'libru',
#   'html',
#   'мюлермонтов',
#   'мцыри',
#   'вкушая',
#   'вкусих',
#   'мало',
#   'меда',
#   'и',
#   'се',
#   'аз',
#   'умираю',
#   'я',
#   'книга',
#   'царств',
#   'немного',
#   'лет',
#   'тому',
#   'назад',
#   'там',
#   'где',
#   'сливаяся',
#   'шумят',
#   'обнявшись',
#   'будто',
#   'две',
#   'сестры',
#   'струи',
#   'арагвы',
#   'и',
#   'куры',
#   'был',
#   'монастырь',
#   'изза',
#   'горы',
#   'и',
#   'нынче',
#   'видит',
#   'пешеход',
#   'столбы',
#   'обрушенных',
#   'ворот',
#   'и',
#   'башни',
#   'и',
#   'церковный',
#   'свод',
#   'но',
#   'не',
#   'курится',
#   'уж',
#   'под',
#   'ним',
#   'кадильниц',
#   'благовонный',
#   'дым',
#   'не',
#   'слышно',
#   'пенье',
#   'в',
#   'поздний',
#   'час',
#   'молящих',
#   'иноков',
#   'за',
#   'нас',
#   'теперь',
#   'один',
#   'старик',
# ...

# %%
type(data)
# Out:
# dask.bag.core.Bag

# %%
words = data.str.split().flatten()

# %%
words.compute()
# Out:
# ['fbzip',
#  'epub',
#  'содержание',
#  'fine',
#  'html',
#  'printed',
#  'version',
#  'txtwordкпк',
#  'libru',
#  'html',
#  'мюлермонтов',
#  'мцыри',
#  'вкушая',
#  'вкусих',
#  'мало',
#  'меда',
#  'и',
#  'се',
#  'аз',
#  'умираю',
#  'я',
#  'книга',
#  'царств',
#  'немного',
#  'лет',
#  'тому',
#  'назад',
#  'там',
#  'где',
#  'сливаяся',
#  'шумят',
#  'обнявшись',
#  'будто',
#  'две',
#  'сестры',
#  'струи',
#  'арагвы',
#  'и',
#  'куры',
#  'был',
#  'монастырь',
#  'изза',
#  'горы',
#  'и',
#  'нынче',
#  'видит',
#  'пешеход',
#  'столбы',
#  'обрушенных',
#  'ворот',
#  'и',
#  'башни',
#  'и',
#  'церковный',
#  'свод',
#  'но',
#  'не',
#  'курится',
#  'уж',
#  'под',
#  'ним',
#  'кадильниц',
#  'благовонный',
#  'дым',
#  'не',
#  'слышно',
#  'пенье',
#  'в',
#  'поздний',
#  'час',
#  'молящих',
#  'иноков',
#  'за',
#  'нас',
#  'теперь',
#  'один',
#  'старик',
#  'седой',
#  'развалин',
#  'страж',
#  'полуживой',
#  'людьми',
#  'и',
# ...

# %%
word_count = words.frequencies()
counts = pd.DataFrame(word_count, columns=['Word', 'Frequency']).sort_values(by="Frequency", ascending = False)

# %%
counts.head(10)
# Out:
#     Word  Frequency
# 15     и        202
# 19     я        110
# 61     в         91
# 90   как         45
# 51    не         43
# 283  мне         41
# 50    но         36
# 104   на         35
# 129   он         34
# 80     с         30

# %% [markdown]
# ### Ну собственно Лермонтов чаще использует предлоги.

# %%
long_words = [word for word in words if len(word) >= 4]

# %%
long_words = db.from_sequence(long_words)

# %%
word_count = long_words.frequencies()
counts = pd.DataFrame(word_count, columns=['Word', 'Frequency']).sort_values(by="Frequency", ascending = False)
counts.head(10)
# Out:
#       Word  Frequency
# 247   лишь         12
# 283   меня         11
# 24   будто         11
# 413  когда         10
# 312   мной         10
# 227  грудь         10
# 159   стал          9
# 174  вдруг          9
# 472   моей          8
# 112  тогда          8

# %% [markdown]
# # 10 самых частых слов

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
counts_for_visual = counts.head(10)

# %%
sns.barplot(data = counts_for_visual, x = 'Word', y = 'Frequency')
plt.show()

# %% [markdown]
# ### Ну вот собственно диагарамма. С тем чтобы убрать предлоги больше часа просидел...
