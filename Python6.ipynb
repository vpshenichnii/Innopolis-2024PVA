# %%
import pandas as pd

# %%
file_path = r"C:\Courses\Innopolis\2024\ПИШ\Часть 2.1\Лекция 17\sales.csv"
df = pd.read_csv(file_path, index_col = 0, nrows = 34866, usecols = range(15))
df.head()
# Out:
#             Date  Year     Month  Customer Age Customer Gender        Country  \
# index
# 0      2/19/2016  2016  February            29               F  United States
# 1      2/20/2016  2016  February            29               F  United States
# 2      2/27/2016  2016  February            29               F  United States
# 3      3/12/2016  2016     March            29               F  United States
# 4      3/12/2016  2016     March            29               F  United States
#
#             State Product Category     Sub Category  Quantity  Unit Cost  \
# index
# 0      Washington      Accessories  Tires and Tubes         1      80.00
# 1      Washington         Clothing           Gloves         2      24.50
# 2      Washington      Accessories  Tires and Tubes         3       3.67
# 3      Washington      Accessories  Tires and Tubes         2      87.50
# 4      Washington      Accessories  Tires and Tubes         3      35.00
#
#        Unit Price  Cost  Revenue
# index
# ...

# %% [markdown]
# ### Методы общей характеристики датафрейма

# %%
df.head(3)
# Out:
#             Date  Year     Month  Customer Age Customer Gender        Country  \
# index
# 0      2/19/2016  2016  February            29               F  United States
# 1      2/20/2016  2016  February            29               F  United States
# 2      2/27/2016  2016  February            29               F  United States
#
#             State Product Category     Sub Category  Quantity  Unit Cost  \
# index
# 0      Washington      Accessories  Tires and Tubes         1      80.00
# 1      Washington         Clothing           Gloves         2      24.50
# 2      Washington      Accessories  Tires and Tubes         3       3.67
#
#        Unit Price  Cost  Revenue
# index
# 0           109.0    80      109
# 1            28.5    49       57
# 2             5.0    11       15

# %%
df.tail()
# Out:
#             Date  Year     Month  Customer Age Customer Gender Country  \
# index
# 34861  3/22/2015  2015     March            38               M  France
# 34862   2/7/2016  2016  February            38               M  France
# 34863  3/13/2015  2015     March            38               M  France
# 34864   4/5/2015  2015     April            38               M  France
# 34865  8/30/2015  2015    August            38               M  France
#
#                    State Product Category    Sub Category  Quantity  \
# index
# 34861  Charente-Maritime            Bikes  Mountain Bikes         1
# 34862     Hauts de Seine            Bikes  Mountain Bikes         2
# 34863     Hauts de Seine            Bikes  Mountain Bikes         1
# 34864     Hauts de Seine            Bikes  Mountain Bikes         3
# 34865     Hauts de Seine            Bikes  Mountain Bikes         1
#
#        Unit Cost   Unit Price  Cost  Revenue
# index
# 34861     2049.0  1487.000000  2049     1487
# ...

# %%
df.shape
# Out:
# (34866, 14)

# %%
df.size
# Out:
# 488124

# %%
df.dtypes
# Out:
# Date                 object
# Year                  int64
# Month                object
# Customer Age          int64
# Customer Gender      object
# Country              object
# State                object
# Product Category     object
# Sub Category         object
# Quantity              int64
# Unit Cost           float64
# Unit Price          float64
# Cost                  int64
# Revenue               int64
# dtype: object

# %%
df.describe()
# Out:
#                Year  Customer Age      Quantity     Unit Cost    Unit Price  \
# count  34866.000000  34866.000000  34866.000000  34866.000000  34866.000000
# mean    2015.569237     36.382895      2.002524    349.880567    389.232485
# std        0.495190     11.112902      0.813936    490.015846    525.319091
# min     2015.000000     17.000000      1.000000      0.670000      0.666667
# 25%     2015.000000     28.000000      1.000000     45.000000     53.666667
# 50%     2016.000000     35.000000      2.000000    150.000000    179.000000
# 75%     2016.000000     44.000000      3.000000    455.000000    521.000000
# max     2016.000000     87.000000      3.000000   3240.000000   5082.000000
#
#                Cost       Revenue
# count  34866.000000  34866.000000
# mean     576.004532    640.870074
# std      690.500395    736.650597
# min        2.000000      2.000000
# 25%       85.000000    102.000000
# 50%      261.000000    319.000000
# 75%      769.000000    902.000000
# ...

# %%
df['Unit Price'].hist(bins = 50)
# Out:
# <Axes: >

# %% [markdown]
# ### Методы агрегации качественных переменных

# %%
df['Country'].unique()
# Out:
# array(['United States', 'France', 'United Kingdom', 'Germany'],
#       dtype=object)

# %%
df['Country'].value_counts()
# Out:
# Country
# United States     18076
# United Kingdom     6421
# Germany            5201
# France             5168
# Name: count, dtype: int64

# %%
df['Sub Category'].value_counts()
# Out:
# Sub Category
# Tires and Tubes      11112
# Bottles and Cages     5295
# Helmets               4176
# Road Bikes            3022
# Mountain Bikes        2737
# Jerseys               2000
# Caps                  1517
# Touring Bikes         1334
# Fenders                762
# Shorts                 566
# Cleaners               545
# Gloves                 480
# Hydration Packs        396
# Socks                  364
# Vests                  312
# Bike Stands            145
# Bike Racks             103
# Name: count, dtype: int64

# %%
df['Customer Gender'].value_counts()
# Out:
# Customer Gender
# M    17805
# F    17061
# Name: count, dtype: int64

# %% [markdown]
# ### Пересечение двух качественных переменных

# %%
pd.crosstab(df['Country'], df['Customer Gender'])
# Out:
# Customer Gender     F     M
# Country
# France           2595  2573
# Germany          2599  2602
# United Kingdom   3168  3253
# United States    8699  9377

# %%
cust_gen_df = df[['Country', 'Customer Gender']].value_counts()

# %%
cust_gen_df
# Out:
# Country         Customer Gender
# United States   M                  9377
#                 F                  8699
# United Kingdom  M                  3253
#                 F                  3168
# Germany         M                  2602
#                 F                  2599
# France          F                  2595
#                 M                  2573
# Name: count, dtype: int64

# %%
cust_gen_df.index
# Out:
# MultiIndex([( 'United States', 'M'),
#             ( 'United States', 'F'),
#             ('United Kingdom', 'M'),
#             ('United Kingdom', 'F'),
#             (       'Germany', 'M'),
#             (       'Germany', 'F'),
#             (        'France', 'F'),
#             (        'France', 'M')],
#            names=['Country', 'Customer Gender'])

# %%
cust_gen_df.loc['United States']
# Out:
# Customer Gender
# M    9377
# F    8699
# Name: count, dtype: int64

# %%
cust_gen_df.loc[:, 'M']
# Out:
# Country
# United States     9377
# United Kingdom    3253
# Germany           2602
# France            2573
# Name: count, dtype: int64

# %%
cust_gen_df.unstack()
# Out:
# Customer Gender     F     M
# Country
# France           2595  2573
# Germany          2599  2602
# United Kingdom   3168  3253
# United States    8699  9377

# %% [markdown]
# ### Сортировка

# %%
france_df = df[df['Country'] == 'France']
france_df
# Out:
#             Date  Year     Month  Customer Age Customer Gender Country  \
# index
# 294    2/20/2016  2016  February            40               F  France
# 295    2/20/2016  2016  February            40               F  France
# 296    2/20/2016  2016  February            40               F  France
# 297    2/20/2016  2016  February            40               F  France
# 298    2/20/2016  2016  February            40               F  France
# ...          ...   ...       ...           ...             ...     ...
# 34861  3/22/2015  2015     March            38               M  France
# 34862   2/7/2016  2016  February            38               M  France
# 34863  3/13/2015  2015     March            38               M  France
# 34864   4/5/2015  2015     April            38               M  France
# 34865  8/30/2015  2015    August            38               M  France
#
#                    State Product Category     Sub Category  Quantity  \
# index
# ...

# %%
france_df.reset_index(drop = True, inplace = True)
france_df
# Out:
#            Date  Year     Month  Customer Age Customer Gender Country  \
# 0     2/20/2016  2016  February            40               F  France
# 1     2/20/2016  2016  February            40               F  France
# 2     2/20/2016  2016  February            40               F  France
# 3     2/20/2016  2016  February            40               F  France
